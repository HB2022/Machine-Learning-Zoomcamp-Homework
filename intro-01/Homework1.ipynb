# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.__version__
# Out:
# '3.0.6'

# %%
df= pd.read_csv('https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv')

# %%
df
# Out:
#       model_year  origin fuel_type         drivetrain  num_doors  \
# 0           2006  Europe  Gasoline  Front-wheel drive          4
# 1           2008  Europe    Diesel  Front-wheel drive          4
# 2           1996    Asia  Gasoline  Front-wheel drive          5
# 3           1989  Europe  Gasoline  Front-wheel drive          4
# 4           1994     USA    Diesel  Front-wheel drive          3
# ...          ...     ...       ...                ...        ...
# 9995        2005     USA  Gasoline    All-wheel drive          4
# 9996        1993    Asia  Gasoline    All-wheel drive          2
# 9997        2014     USA  Gasoline    All-wheel drive          3
# 9998        2004     USA    Hybrid   Rear-wheel drive          5
# 9999        2011     USA    Diesel  Front-wheel drive          4
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                    2180              6       243.0            3870
# ...

# %%
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %%
df.shape
# Out:
# (10000, 11)

# %%
df['fuel_type'].nunique()
# Out:
# 3

# %%
df.isna().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
(df.isna().sum() >0).sum()
# Out:
# np.int64(2)

# %%
asia_cars= df[df['origin'] == 'Asia']

# %%
asia_cars
# Out:
#       model_year origin fuel_type         drivetrain  num_doors  \
# 2           1996   Asia  Gasoline  Front-wheel drive          5
# 6           1992   Asia  Gasoline  Front-wheel drive          2
# 8           1997   Asia  Gasoline   Rear-wheel drive          3
# 10          1978   Asia  Gasoline    All-wheel drive          3
# 15          2007   Asia    Diesel  Front-wheel drive          4
# ...          ...    ...       ...                ...        ...
# 9984        2011   Asia  Gasoline  Front-wheel drive          3
# 9987        2004   Asia    Diesel    All-wheel drive          3
# 9990        1975   Asia    Diesel  Front-wheel drive          4
# 9994        1993   Asia  Gasoline   Rear-wheel drive          2
# 9996        1993   Asia  Gasoline    All-wheel drive          2
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 2                    2320              6       267.0            4240
# ...

# %%
Max_fuelefficiency_Asiacars = asia_cars['fuel_efficiency_mpg'].max()

# %%
print(Max_fuelefficiency_Asiacars)
# Out:
# 41.2

# %%
Median_horsepower1 = df['horsepower'].median()

# %%
print(Median_horsepower1)
# Out:
# 254.0

# %%
Must_frequent_horsepower = df['horsepower'].mode()[0]

# %%
print(Must_frequent_horsepower)
# Out:
# 252.0

# %%
df['horsepower'] = df['horsepower'].fillna(Must_frequent_horsepower)

# %%
Median_horsepower2 = df['horsepower'].median()

# %%
print(Median_horsepower2)
# Out:
# 252.0

# %%
if Median_horsepower1 == Median_horsepower2:
              print("Median has'nt changed")
if Median_horsepower1 > Median_horsepower2:
              print("Median has decreased")
else: print("Median has increased")
# Out:
# Median has decreased

# %%
asia_cars
# Out:
#       model_year origin fuel_type         drivetrain  num_doors  \
# 2           1996   Asia  Gasoline  Front-wheel drive          5
# 6           1992   Asia  Gasoline  Front-wheel drive          2
# 8           1997   Asia  Gasoline   Rear-wheel drive          3
# 10          1978   Asia  Gasoline    All-wheel drive          3
# 15          2007   Asia    Diesel  Front-wheel drive          4
# ...          ...    ...       ...                ...        ...
# 9984        2011   Asia  Gasoline  Front-wheel drive          3
# 9987        2004   Asia    Diesel    All-wheel drive          3
# 9990        1975   Asia    Diesel  Front-wheel drive          4
# 9994        1993   Asia  Gasoline   Rear-wheel drive          2
# 9996        1993   Asia  Gasoline    All-wheel drive          2
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 2                    2320              6       267.0            4240
# ...

# %%
X = asia_cars[['vehicle_weight', 'model_year']].head(7).to_numpy()

# %%
X
# Out:
# array([[4240, 1996],
#        [4310, 1992],
#        [4230, 1997],
#        [4420, 1978],
#        [3950, 2007],
#        [4750, 2021],
#        [4450, 2019]])

# %%
XT = X.T

# %%
XT
# Out:
# array([[4240, 4310, 4230, 4420, 3950, 4750, 4450],
#        [1996, 1992, 1997, 1978, 2007, 2021, 2019]])

# %%
XTX =XT @ X

# %%
XTX
# Out:
# array([[131950500,  60750580],
#        [ 60750580,  28041424]])

# %%
XTX_inv = np.linalg.inv(XTX)

# %%
y = [ 1100, 1300, 800, 900, 1000, 1100, 1200]

# %%
y
# Out:
# [1100, 1300, 800, 900, 1000, 1100, 1200]

# %%
w = XTX_inv @ X.T @ y

# %%
w
# Out:
# array([0.13644777, 0.2327492 ])

# %%
s = w.sum()

# %%
print(s)
# Out:
# 0.36919696904925486
